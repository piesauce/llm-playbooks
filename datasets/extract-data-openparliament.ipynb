# %%
import pandas as pd
from sqlalchemy import create_engine, inspect, text
import json
import os

#Connect to database
engine = create_engine("postgresql://joey@localhost:5432/openparliament2")
inspector = inspect(engine)
print(inspector.get_table_names(schema="public"))
# Out:
# ['accounts_logintoken', 'activity_activity', 'alerts_seenitem', 'auth_group', 'auth_user_groups', 'bills_bill_similar_bills', 'auth_user', 'auth_message', 'auth_user_user_permissions', 'bills_bill', 'alerts_topic', 'alerts_subscription', 'accounts_user', 'bills_membervote', 'bills_billtext', 'bills_votequestion', 'bills_partyvote', 'committees_committee', 'committees_committeemeeting_activities', 'committees_committeeinsession', 'committees_committeemeeting', 'committees_committeereport', 'django_content_type', 'core_sitenews', 'core_politician', 'core_session', 'contact_contactthread', 'django_admin_log', 'core_electedmember', 'core_party', 'core_riding', 'core_partyalternatename', 'core_ridingpostcodecache', 'core_electedmember_sessions', 'core_politicianinfo', 'django_migrations', 'django_flatpage_sites', 'django_flatpage', 'django_session', 'elections_election', 'financials_contributor', 'sentry_groupedmessage', 'hansards_oldsequencemapping', 'indexer_index', 'labs_haiku', 'sentry_filtervalue', 'hansards_oldslugmapping', 'south_migrationhistory', 'hansards_statement_mentioned_politicians', 'hansards_statement_bills', 'search_indexingtask', 'hansards_statement', 'summaries_summary', 'summaries_summarypoll', 'text_analysis_textanalysis', 'committees_committeeactivity', 'committees_committeeactivityinsession', 'auth_permission', 'auth_group_permissions', 'contact_contactmessage', 'django_site', 'hansards_document', 'elections_candidacy', 'financials_contribution', 'sentry_message']

# %%
for tbl in inspector.get_table_names(schema="public"):
    print(f"\n=== {tbl} ===")
    df = pd.read_sql(f"SELECT * FROM {tbl} LIMIT 5", engine)
    display(df)
# Out:
# === accounts_logintoken ===
# Empty DataFrame
# Columns: [token, email, created, requesting_ip, used, login_ip, post_login_url]
# Index: []
# === activity_activity ===
# Empty DataFrame
# Columns: [id, date, variety, politician_id, payload, guid, active]
# Index: []
# === alerts_seenitem ===
# Empty DataFrame
# Columns: [id, topic_id, item_id, timestamp]
# Index: []
# === auth_group ===
# Empty DataFrame
# Columns: [id, name]
# Index: []
# === auth_user_groups ===
# Empty DataFrame
# Columns: [id, user_id, group_id]
# Index: []
# === bills_bill_similar_bills ===
# Empty DataFrame
# Columns: [id, from_bill_id, to_bill_id]
# Index: []
# === auth_user ===
# Empty DataFrame
# Columns: [id, username, first_name, last_name, email, password, is_staff, is_active, is_superuser, last_login, date_joined]
# Index: []
# === auth_message ===
# Empty DataFrame
# Columns: [id, user_id, message]
# Index: []
# === auth_user_user_permissions ===
# Empty DataFrame
# Columns: [id, user_id, permission_id]
# Index: []
# === bills_bill ===
#      id                                            name_en number  \
# 0  7885  An Act to amend the Criminal Code and the Depa...   C-51
# 1  7931  An Act for granting to Her Majesty certain sum...   C-41
# 2  7880  An Act to amend the Criminal Code (victim surc...   C-28
# 3  7769  An Act to amend the Income Tax Act (tax credit...  C-240
# 4  1882  An Act to amend the Transportation of Dangerou...    C-9
#
#    number_only  sponsor_member_id  privatemember  sponsor_politician_id   law  \
# 0           51               4206          False                  10273  True
# 1           41               1336          False                     44  True
# 2           28               4206          False                  10273  None
# 3          240               4360           True                   8726  None
# 4            9                326          False                    401  True
#
#         added institution  ...                      short_title_fr  \
# 0  2016-10-28           C  ...
# 1  2017-03-21           C  ...  Loi de crédits no 1 pour 2017-2018
# 2  2016-10-21           C  ...
# 3  2016-02-25           C  ...
# 4  2010-05-27           C  ...
#
#   status_date  introduced text_docid             status_code  \
# 0  2018-12-13  2017-06-06   10276765        RoyalAssentGiven
# 1  2017-03-30  2017-03-21    8852843        RoyalAssentGiven
# 2  2016-10-21  2016-10-21    8520485       HouseAt2ndReading
# 3  2017-11-29  2016-02-25    8126924  WillNotBeProceededWith
# 4  2009-05-14  2009-02-02    3944893        RoyalAssentGiven
#
#                                      billstages_json legisinfo_id  \
# 0  {"BillId": 0, "HouseBillStages": [{"BillStageI...      9002286
# 1  {"BillId": 0, "HouseBillStages": [{"BillStageI...      8834412
# 2  {"BillId": 0, "HouseBillStages": [{"BillStageI...      8374778
# 3  {"BillId": 0, "HouseBillStages": [{"BillStageI...      8112051
# 4  {"BillId": 0, "HouseBillStages": [{"BillStageI...      3635134
#
#   library_summary_available  session_id  latest_debate_date
# 0                      True        42-1          2017-12-11
# 1                     False        42-1          2017-03-21
# 2                      True        42-1          2016-11-24
# 3                     False        42-1          2016-10-26
# 4                      True        40-2          2009-05-14
#
# [5 rows x 22 columns]
# === alerts_topic ===
# Empty DataFrame
# Columns: [id, query, created, last_checked, last_found]
# Index: []
# === alerts_subscription ===
# Empty DataFrame
# Columns: [id, topic_id, user_id, created, active, last_sent]
# Index: []
# === accounts_user ===
# Empty DataFrame
# Columns: [id, email, email_bouncing, created, last_login, email_bounce_reason, name, data]
# Index: []
# === bills_membervote ===
#    member_id  politician_id  votequestion_id      id vote  dissent
# 0        364            414             1023  238992    N     True
# 1       1250              6             1023  238989    N     True
# 2       1268             77              991  229170    Y     True
# 3       3672            238              990  228807    Y     True
# 4       3654            219              990  228790    Y     True
# === bills_billtext ===
#    id  bill_id    docid                          created  \
# 0   1     2209  5080434 2012-10-05 21:50:54.858116+00:00
# 1   8     2813  5117697 2012-10-05 21:50:59.634296+00:00
# 2   9     2812  5117696 2012-10-05 21:51:00.199777+00:00
# 3  29     6476  5339072 2012-10-05 21:51:46.780951+00:00
# 4  34     6528  5506769 2012-10-05 21:51:50.584260+00:00
#
#                                              text_en text_fr summary_en
# 0  C-1\nFirst Session, Forty-first Parliament,\n6...
# 1  First Session, Forty-first Parliament,\n60 Eli...
# 2  First Session, Forty-first Parliament,\n60 Eli...
# 3  First Session, Forty-first Parliament,\n60 Eli...
# 4  First Session, Forty-first Parliament,\n60-61 ...
# === bills_votequestion ===
#                                       description_en  nay_total bill_id  \
# 0  That, notwithstanding any Standing Order or us...         91    None
# 1  That, given the undisputed privileges of Parli...        142    None
# 2  That, in the opinion of the House, the governm...          3    None
# 3  That the motion be amended:\n    (\n    a) by ...        214    None
# 4  That the amendment be amended by adding after ...        159    None
#
#    paired_total  number session_id result        date    id  yea_total  \
# 0             6     180       40-3      Y  2011-02-14  1071        180
# 1             0     187       40-3      Y  2011-02-28  1078        145
# 2            10     194       40-3      Y  2011-03-02  1085        269
# 3             8     196       40-3      N  2011-03-08  1087         77
# 4             0       1       41-1      N  2011-06-08  1097        133
#
#    context_statement_id description_fr
# 0                739927
# 1                741233
# 2                741754
# 3                742853
# 4                746079
# === bills_partyvote ===
#   vote  party_id  votequestion_id    id  disagreement
# 0    N         1             1043  3345      0.000000
# 1    F         2             1043  3346      0.400000
# 2    Y         3             1043  3347      0.000000
# 3    F         4             1043  3348      0.287879
# 4    F         1             1042  3349      0.360294
# === committees_committee ===
#     id                                            name_en  \
# 0  117  Subcommittee on Bill C-28 (39th Parliament, 2n...
# 1  118  Subcommittee on Oil and Gas and Other Energy P...
# 2  120  Subcommittee on the Conflict of Interest Code ...
# 3  114            Bill C-2 (39th Parliament, 2nd Session)
# 4  115           Bill C-20 (39th Parliament, 2nd Session)
#
#                                        short_name_en  \
# 0  Subcommittee on Bill C-28 (39th Parliament, 2n...
# 1  Subcommittee on Oil and Gas and Other Energy P...
# 2  Subcommittee on the Conflict of Interest Code ...
# 3            Bill C-2 (39th Parliament, 2nd Session)
# 4           Bill C-20 (39th Parliament, 2nd Session)
#
#                         slug  parent_id  display  \
# 0     finance-bill-c-28-39-2       72.0     True
# 1                 gas-prices       85.0     True
# 2  conflict-of-interest-code       98.0     True
# 3              bill-c-2-39-2        NaN     True
# 4             bill-c-20-39-2        NaN     True
#
#                                              name_fr  \
# 0              Sous-comité sur le projet de loi C-28
# 1  Sous-comité sur le prix du pétrole et du gaz e...
# 2  Sous-comité du Code régissant les conflits d'i...
# 3                                  Projet de loi C-2
# 4                                 Projet de loi C-20
#
#                                        short_name_fr  joint
# 0              Sous-comité sur le projet de loi C-28  False
# 1  Sous-comité sur le prix du pétrole et du gaz e...  False
# 2  Sous-comité du Code régissant les conflits d'i...  False
# 3                                  Projet de loi C-2  False
# 4                                 Projet de loi C-20  False
# === committees_committeemeeting_activities ===
#       id  committeemeeting_id  committeeactivity_id
# 0  13126                 9267                  2687
# 1  13127                 9268                  2687
# 2  13128                 9269                  2687
# 3  13129                 9270                  2687
# 4  13130                 9271                  2687
# === committees_committeeinsession ===
#    id session_id  committee_id acronym
# 0  54       39-1            54    AANO
# 1  55       39-1            55    SAAN
# 2  56       39-1            56    ETHI
# 3  57       39-1            57    SETH
# 4  58       39-1            58    AGRI
# === committees_committeemeeting ===
#       id        date start_time  end_time  committee_id  number session_id  \
# 0  10386  2007-02-15   09:08:00  11:02:00            94      36       39-1
# 1  10387  2007-02-13   09:04:00  11:06:00            94      35       39-1
# 2  10388  2007-02-08   09:06:00  11:02:00            94      34       39-1
# 3  10389  2007-02-06   15:29:00  17:03:00            94      33       39-1
# 4  10390  2007-02-01   09:05:00  10:27:00            94      32       39-1
#
#    minutes notice  evidence_id  in_camera  travel  webcast  televised  \
# 0  2701761   None        10202      False   False     True      False
# 1  2691357   None        10203      False   False     True      False
# 2  2679757   None        10204      False   False     True      False
# 3  2669681   None        10205      False   False     True      False
# 4  2655008   None        10206      False   False     True      False
#
#    source_id
# 0    1892119
# 1    1890460
# 2    1879337
# 3    1860154
# 4    1856511
# === committees_committeereport ===
#     id  committee_id session_id  number  \
# 0  110           112       39-1       6
# 1  111           112       39-1       5
# 2  112           112       39-1       4
# 3  113           112       39-1       3
# 4  114           112       39-1       2
#
#                                              name_en  source_id adopted_date  \
# 0  Support for Veterans and other Victims of Post...    3042769   2007-06-12
# 1  Bill C-287, An Act respecting a National Peace...    2887905   2007-05-01
# 2  Bill C-287, An Act respecting a National Peace...    2860036   2007-04-24
# 3            Designation of Room 112-N, Centre Block    2834076   2007-04-17
# 4  A helping Hand for Veterans: Mandate for a Vet...    2711640   2007-02-06
#
#   presented_date  government_response parent_id name_fr
# 0     2007-06-15                False      None
# 1     2007-05-03                False      None
# 2     2007-04-25                False      None
# 3     2007-04-18                False      None
# 4     2007-02-22                False      None
# === django_content_type ===
#    id     app_label        model
# 0   1          auth   permission
# 1   2          auth        group
# 2   3          auth         user
# 3   5  contenttypes  contenttype
# 4   6      sessions      session
# === core_sitenews ===
# Empty DataFrame
# Columns: [date, text, active, id, title]
# Index: []
# === core_politician ===
#      id                 name   name_given name_family   dob gender headshot  \
# 0  7042   A. David H. Bailie  A. David H.      Bailie  None            None
# 1  7153     A. James Donahue     A. James     Donahue  None            None
# 2  8191  A.B. Short Tompkins   A.B. Short    Tompkins  None            None
# 3  7144     A.R. Art Canning     A.R. Art     Canning  None            None
# 4  7347  Aaron G. De Meester     Aaron G.  De Meester  None            None
#
#   slug headshot_thumbnail
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# === core_session ===
#      id                          name       start         end  parliamentnum  \
# 0  43-2  43rd Parliament, 2nd session  2020-09-23  2021-08-15             43
# 1  43-1  43rd Parliament, 1st session  2019-11-12  2020-09-22             43
# 2  42-1  42nd Parliament, 1st session  2015-12-03  2019-09-11             42
# 3  41-2  41st Parliament, 2nd session  2013-10-16  2015-08-02             41
# 4  41-1  41st Parliament, 1st session  2011-06-02  2013-09-13             41
#
#    sessnum
# 0        2
# 1        1
# 2        1
# 3        2
# 4        1
# === contact_contactthread ===
# Empty DataFrame
# Columns: [id, code_email, code_web, politician_id, from_email, created, confirmed, share, why, from_postcode, from_street_address, published, surveys_remaining]
# Index: []
# === django_admin_log ===
# Empty DataFrame
# Columns: [id, action_time, user_id, content_type_id, object_id, object_repr, action_flag, change_message]
# Index: []
# === core_electedmember ===
#      id  politician_id  riding_id  party_id    end_date  start_date
# 0  4015           2693      70159         5  2000-09-11  2000-04-02
# 1  4016           2693      70159         4  2001-01-28  2000-09-12
# 2  4017           4136      59023         4  2005-05-23  2002-01-28
# 3  4018           4983      70116         5  2004-05-23  2002-08-20
# 4  4019           5258      70139         5  2003-03-14  2003-01-16
# === core_party ===
#    id                                            name_en slug  \
# 0  32                       Abolitionist Party of Canada
# 1  24  Animal Alliance Environment Voters Party of Ca...
# 2  30                                       Canada Party
# 3  16                              Canadian Action Party
# 4  10                 Christian Heritage Party of Canada
#
#                                        short_name_en  \
# 0                       Abolitionist Party of Canada
# 1  Animal Alliance Environment Voters Party of Ca...
# 2                                       Canada Party
# 3                              Canadian Action Party
# 4                 Christian Heritage Party of Canada
#
#                                              name_fr  \
# 0                       Abolitionist Party of Canada
# 1  Animal Alliance Environment Voters Party of Ca...
# 2                                       Canada Party
# 3                              Canadian Action Party
# 4                 Christian Heritage Party of Canada
#
#                                        short_name_fr
# 0                       Abolitionist Party of Canada
# 1  Animal Alliance Environment Voters Party of Ca...
# 2                                       Canada Party
# 3                              Canadian Action Party
# 4                 Christian Heritage Party of Canada
# === core_riding ===
#       id                                      name_en province  \
# 0  10002      Bonavista--Gander--Grand Falls--Windsor       NL
# 1  10003                Humber--St. Barbe--Baie Verte       NL
# 2  10005                  Random--Burin--St. George's       NL
# 3  12007  Cumberland--Colchester--Musquodoboit Valley       NS
# 4  12008                     Sackville--Eastern Shore       NS
#
#                                         slug   edid name_fr  current
# 0       bonavista-gander-grand-falls-windsor  10002            False
# 1                 humber-st-barbe-baie-verte  10003            False
# 2                   random-burin-st-george-s  10005            False
# 3  cumberland-colchester-musquodoboit-valley  12007            False
# 4                    sackville-eastern-shore  12008            False
# === core_partyalternatename ===
#                                                 name  party_id
# 0  forces et démocratie - allier les forces de no...        39
# 1                                                atn        40
# 2                                   alliance du nord        40
# 3                             democratic advancement        41
# 4                             marxist-leninist party        19
# === core_ridingpostcodecache ===
# Empty DataFrame
# Columns: [postcode, source, timestamp, riding_id]
# Index: []
# === core_electedmember_sessions ===
#      id  electedmember_id session_id
# 0  4649              4031       40-3
# 1  4650              4032       40-3
# 2  4651              4033       40-3
# 3  4652               929       40-3
# 4  4653               929       40-2
# === core_politicianinfo ===
#    politician_id  id            value   schema created
# 0            607   7   brentrathgeber  twitter    None
# 1            596  10        brucehyer  twitter    None
# 2             24  12  Carolyn_Bennett  twitter    None
# 3            612  13     Cathy_McLeod  twitter    None
# 4            113  14    cherylgallant  twitter    None
# === django_migrations ===
#    id           app                                   name  \
# 0   1  contenttypes                           0001_initial
# 1   2          auth                           0001_initial
# 2   3         admin                           0001_initial
# 3   4  contenttypes          0002_remove_content_type_name
# 4   5          auth  0002_alter_permission_name_max_length
#
#                            applied
# 0 2016-01-21 17:44:45.045175+00:00
# 1 2016-01-21 17:44:45.080385+00:00
# 2 2016-01-21 17:44:45.105360+00:00
# 3 2016-01-21 17:44:45.181843+00:00
# 4 2016-01-21 17:44:45.662172+00:00
# === django_flatpage_sites ===
# Empty DataFrame
# Columns: [id, flatpage_id, site_id]
# Index: []
# === django_flatpage ===
# Empty DataFrame
# Columns: [id, url, title, content, enable_comments, template_name, registration_required]
# Index: []
# === django_session ===
# Empty DataFrame
# Columns: [session_key, session_data, expire_date]
# Index: []
# === elections_election ===
#    id        date  byelection
# 0  24  2009-11-09        True
# 1   1  2008-10-14       False
# 2   7  2008-03-17        True
# 3   8  2007-09-17        True
# 4   9  2006-11-27        True
# === financials_contributor ===
# Empty DataFrame
# Columns: [id, name, name_given, name_family, city, province, postcode]
# Index: []
# === sentry_groupedmessage ===
# Empty DataFrame
# Columns: [id, logger, class_name, level, message, traceback, view, checksum, status, times_seen, last_seen, first_seen, data]
# Index: []
# === hansards_oldsequencemapping ===
#    id  document_id  sequence                      slug
# 0   1          161         0              procedural-1
# 1   2          161         1  the-clerk-of-the-house-1
# 2   3          161         5          peter-milliken-1
# 3   4          161        15             the-speaker-1
# 4   5          161        20             the-speaker-2
# === indexer_index ===
# Empty DataFrame
# Columns: [id, app_label, module_name, column, value, object_id]
# Index: []
# === labs_haiku ===
# Empty DataFrame
# Columns: [id, line1, line2, line3, attribution, attribution_url, worthy]
# Index: []
# === sentry_filtervalue ===
# Empty DataFrame
# Columns: [id, key, value]
# Index: []
# === hansards_oldslugmapping ===
# Empty DataFrame
# Columns: [id, old_slug, new_slug, document_id]
# Index: []
# === south_migrationhistory ===
# Empty DataFrame
# Columns: [id, app_name, migration, applied]
# Index: []
# === hansards_statement_mentioned_politicians ===
#       id  statement_id  politician_id
# 0  85669        629544            396
# 1  85670        629551            429
# 2  85671        629552            156
# 3  85672        629555            247
# 4  85673        629559            132
# === hansards_statement_bills ===
#    id  statement_id  bill_id
# 0   2        219345      287
# 1   3        219402      218
# 2   4        219403      219
# 3   5        219427      159
# 4   6        219643      254
# === search_indexingtask ===
# Empty DataFrame
# Columns: [id, action, identifier, timestamp, content_type_id, object_id]
# Index: []
# === hansards_statement ===
#        id  document_id                       time                h1_en  \
# 0  645328          388  2008-02-14 13:15:00-05:00  Routine Proceedings
# 1  232373         1878  2001-05-03 13:50:00-04:00    Government Orders
# 2  170961          944  1999-05-10 16:05:00-04:00    Government Orders
# 3   27684         1138  1994-11-18 10:00:00-05:00
# 4  645329          388  2008-02-14 13:15:00-05:00  Routine Proceedings
#
#                                         h2_en  member_id  \
# 0      Questions Passed as Orders for Returns        NaN
# 1  Federal-Provincial Fiscal Arrangements Act     2611.0
# 2             Income Tax Amendments Act, 1998     3066.0
# 3                                   Privilege        NaN
# 4      Questions Passed as Orders for Returns     1534.0
#
#                            who_en  \
# 0
# 1           Ms. Marlene Catterall
# 2  Mr. Grant Hill (Macleod, Ref.)
# 3                     The Speaker
# 4                Mr. Tom Lukiwski
#
#                                           content_en  sequence  wordcount  \
# 0  <p class="procedural" data-HoCid="906765">(Ret...        86          2
# 1  <p>Mr. Speaker, I rise on a point of order. I ...        89         39
# 2  <p>Mr. Speaker, today I would like to take a d...       210       1793
# 3  <p>My colleagues, I am now ready to rule on th...         0        972
# 4  <p data-HoCid="906766" data-originallang="en">...        87         13
#
#    ...                 slug                                urlcache h1_fr  \
# 0  ...         procedural-3        /debates/2008/2/14/procedural-3/
# 1  ...  marlene-catterall-1  /debates/2001/5/3/marlene-catterall-1/
# 2  ...         grant-hill-1        /debates/1999/5/10/grant-hill-1/
# 3  ...        the-speaker-1      /debates/1994/11/18/the-speaker-1/
# 4  ...       tom-lukiwski-7      /debates/2008/2/14/tom-lukiwski-7/
#
#    h2_fr h3_fr who_fr who_context_fr wordcount_en bill_debate_stage  \
# 0                                            None
# 1                                            None
# 2                                            None
# 3                                            None
# 4                                            None
#
#   bill_debated_id
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
#
# [5 rows x 29 columns]
# === summaries_summary ===
# Empty DataFrame
# Columns: [id, summary_type, identifier, summary_text, summarized_statement_count, created, public, metadata, latest_statement_date, summary_json]
# Index: []
# === summaries_summarypoll ===
# Empty DataFrame
# Columns: [id, vote, created, user_ip, summary_id, user_agent]
# Index: []
# === text_analysis_textanalysis ===
# Empty DataFrame
# Columns: [id, key, lang, updated, expires, probability_data_json]
# Index: []
# === committees_committeeactivity ===
#      id  committee_id                                            name_en  \
# 0  2687           112  Veterans Independence Program and Health Care ...
# 1  2688           112                                 Committee Business
# 2  2689           112  Bill C-287, An Act respecting a National Peace...
# 3  2690           112                            Veterans Bill of Rights
# 4  2691           112                                 Veterans Ombudsman
#
#                                              name_fr  study
# 0  Programme pour l'autonomie des anciens combatt...   True
# 1                                  Travaux du Comité  False
# 2  Projet de loi C-287, Loi instituant la Journée...   True
# 3     Déclaration des droits des anciens combattants   True
# 4                  Ombudsman des anciens combattants   True
# === committees_committeeactivityinsession ===
#     id  activity_id session_id  source_id
# 0  339         2687       39-1    1566412
# 1  340         2688       39-1    1527149
# 2  341         2689       39-1    1810916
# 3  342         2690       39-1    1548872
# 4  343         2691       39-1    1548600
# === auth_permission ===
# Empty DataFrame
# Columns: [id, name, content_type_id, codename]
# Index: []
# === auth_group_permissions ===
# Empty DataFrame
# Columns: [id, group_id, permission_id]
# Index: []
# === contact_contactmessage ===
# Empty DataFrame
# Columns: [id, thread_id, from_name, from_raw, message_display, message, message_raw, subject, time, sent, published, from_politician, survey, surveys_remaining, last_survey]
# Index: []
# === django_site ===
# Empty DataFrame
# Columns: [id, domain, name]
# Index: []
# === hansards_document ===
#      id        date number session_id most_frequent_word  \
# 0  2385  2011-09-21     17       41-1              crime
# 1  2441  2012-02-02     72       41-1            seniors
# 2  2392  2011-09-29     23       41-1            economy
# 3  2439  2012-01-31     70       41-1               plan
# 4  2413  2011-11-04     44       41-1             judges
#
#                           wordcloud document_type  source_id  downloaded  \
# 0  autoimg/wordcloud/2011-09-21.png             D    5127416        True
# 1  autoimg/wordcloud/2012-02-02.png             D    5354648        True
# 2  autoimg/wordcloud/2011-09-29.png             D    5140416        True
# 3  autoimg/wordcloud/2012-01-31.png             D    5347027        True
# 4  autoimg/wordcloud/2011-11-04.png             D    5235852        True
#
#    public  multilingual  skip_parsing xml_source_url first_imported  \
# 0    True          True         False                          None
# 1    True          True         False                          None
# 2    True          True         False                          None
# 3    True          True         False                          None
# 4    True          True         False                          None
#
#   last_imported  skip_redownload
# 0          None            False
# 1          None            False
# 2          None            False
# 3          None            False
# 4          None            False
# === elections_candidacy ===
#      id  candidate_id  riding_id  party_id  election_id         occupation  \
# 0  5366          4247      46007         4            4  insurance broker
# 1  5367          4248      46007        26            4       businessman
# 2  5368          4249      46007         5            4            farmer
# 3  5369          4250      46007         2            4     staff officer
# 4  5370           287      46008        25            4    senior counsel
#
#    votetotal  elected  votepercent
# 0       6133    False        17.82
# 1       5339    False        15.51
# 2       3558    False        10.34
# 3       2073    False         6.02
# 4      21358     True        52.76
# === financials_contribution ===
# Empty DataFrame
# Columns: [id, contributor_id, amount, amount_monetary, amount_nonmonetary, date, individual_recipient_id]
# Index: []
# === sentry_message ===
# Empty DataFrame
# Columns: [id, logger, class_name, level, message, traceback, view, url, server_name, checksum, datetime, data, group_id, site]
# Index: []

# %%
#Helper code to extract tables with content relating to proceedings and analyze tables of interest 

tables_with_proceedings = [
    "bills_bill",
    "bills_billtext",
    "bills_votequestion",
    "hansards_statement"
]

#Helper function to investigate individual tables

def investigate_table(tbl):
    print(f"\n=== {tbl} ===")

    df = pd.read_sql(f"SELECT * FROM {tbl} LIMIT 3", engine)
    
    # list of column names
    print("Columns:")
    print(list(df.columns))
    
    # # column types
    # print("\nColumn dtypes:")
    # for col, dtype in df.dtypes.items():
    #     print(f" - {col}: {dtype}")
    
    # # show the sample rows
    # display(df)

for table in tables_with_proceedings:
    investigate_table(table)

#investigate_table(tables_with_proceedings[3])
# Out:
# === bills_bill ===
# Columns:
# ['id', 'name_en', 'number', 'number_only', 'sponsor_member_id', 'privatemember', 'sponsor_politician_id', 'law', 'added', 'institution', 'name_fr', 'short_title_en', 'short_title_fr', 'status_date', 'introduced', 'text_docid', 'status_code', 'billstages_json', 'legisinfo_id', 'library_summary_available', 'session_id', 'latest_debate_date']
#
# === bills_billtext ===
# Columns:
# ['id', 'bill_id', 'docid', 'created', 'text_en', 'text_fr', 'summary_en']
#
# === bills_votequestion ===
# Columns:
# ['description_en', 'nay_total', 'bill_id', 'paired_total', 'number', 'session_id', 'result', 'date', 'id', 'yea_total', 'context_statement_id', 'description_fr']
#
# === hansards_statement ===
# Columns:
# ['id', 'document_id', 'time', 'h1_en', 'h2_en', 'member_id', 'who_en', 'content_en', 'sequence', 'wordcount', 'politician_id', 'procedural', 'h3_en', 'who_hocid', 'content_fr', 'statement_type', 'written_question', 'source_id', 'who_context_en', 'slug', 'urlcache', 'h1_fr', 'h2_fr', 'h3_fr', 'who_fr', 'who_context_fr', 'wordcount_en', 'bill_debate_stage', 'bill_debated_id']

# %%
columns_of_interest = {
    "bills_bill":['id','text_docid','name_en','status_code','law'],
    "bills_billtext":['bill_id','docid','text_en','summary_en'],
    "bills_votequestion":['id','bill_id','description_en','result'],
    "hansards_statement":['id','document_id','h1_en','h2_en','content_en'],
}

#Create new dataframes for tables we care about, with only columns of interest

for table, cols in columns_of_interest.items():
    cols_sql = ", ".join(f'"{c}"' for c in cols)
    sql = f'SELECT {cols_sql} FROM public."{table}"'
    df = pd.read_sql(sql, engine)
    # Dynamically assign to a variable like bills_bill_clean, etc.
    globals()[f"{table}_clean"] = df

# %%
#Check new dataframes

clean_dfs = [name for name in globals() if name.endswith('_clean')]

for df_name in clean_dfs:
    print(f"\n--- {df_name} ---")
    display(globals()[df_name].head(3))
# Out:
# --- bills_bill_clean ---
#      id  text_docid                                            name_en  \
# 0  7885  10276765.0  An Act to amend the Criminal Code and the Depa...
# 1  7931   8852843.0  An Act for granting to Her Majesty certain sum...
# 2  7880   8520485.0  An Act to amend the Criminal Code (victim surc...
#
#          status_code   law
# 0   RoyalAssentGiven  True
# 1   RoyalAssentGiven  True
# 2  HouseAt2ndReading  None
# --- bills_billtext_clean ---
#    bill_id    docid                                            text_en  \
# 0     2209  5080434  C-1\nFirst Session, Forty-first Parliament,\n6...
# 1     2813  5117697  First Session, Forty-first Parliament,\n60 Eli...
# 2     2812  5117696  First Session, Forty-first Parliament,\n60 Eli...
#
#   summary_en
# 0
# 1
# 2
# --- bills_votequestion_clean ---
#      id  bill_id                                     description_en result
# 0  1071      NaN  That, notwithstanding any Standing Order or us...      Y
# 1  1078      NaN  That, given the undisputed privileges of Parli...      Y
# 2  1085      NaN  That, in the opinion of the House, the governm...      Y
# --- hansards_statement_clean ---
#        id  document_id                h1_en  \
# 0  645328          388  Routine Proceedings
# 1  232373         1878    Government Orders
# 2  170961          944    Government Orders
#
#                                         h2_en  \
# 0      Questions Passed as Orders for Returns
# 1  Federal-Provincial Fiscal Arrangements Act
# 2             Income Tax Amendments Act, 1998
#
#                                           content_en
# 0  <p class="procedural" data-HoCid="906765">(Ret...
# 1  <p>Mr. Speaker, I rise on a point of order. I ...
# 2  <p>Mr. Speaker, today I would like to take a d...

# %%
# HANSARDS STATEMENT AGGREGATION

df_statement_per_document = (
    hansards_statement_clean
    .groupby('document_id')
    .apply(
        lambda grp: grp[['h1_en','h2_en','content_en']]
                   .to_dict(orient='records')
    )
    .reset_index(name='hansards_statements')
)

# %%
# BILLS AGGREGATION

df_docids_agg = (
    bills_billtext_clean
      .groupby('bill_id')['docid']
      .apply(list)
      .reset_index(name='text_docid')
)

df_texts_agg = (
    bills_billtext_clean
      .groupby('bill_id')
      .apply(lambda d: d[['docid','text_en','summary_en']]
                       .to_dict(orient='records'))
      .reset_index(name='bill_texts')
)

df_votes_agg = (
    bills_votequestion_clean
      .groupby('bill_id')
      .apply(lambda d: d[['id','description_en','result']]
                       .to_dict(orient='records'))
      .reset_index(name='vote_questions')
)

bills_master = (
    bills_bill_clean
      .rename(columns={'id':'bill_id'})
      .drop(columns=['text_docid'])
)

df_bills_merged = (
    bills_master
    .merge(df_docids_agg, on='bill_id', how='left')
    .merge(df_texts_agg,   on='bill_id', how='left')
    .merge(df_votes_agg,   on='bill_id', how='left')
)

# 3) Convert any missing entries into empty lists
for col in ('text_docid','bill_texts','vote_questions'):
    df_bills_merged[col] = df_bills_merged[col].apply(lambda x: x if isinstance(x, list) else [])

# 4) Preview
df_bills_merged.head()
# Out:
#    bill_id                                            name_en  \
# 0     7885  An Act to amend the Criminal Code and the Depa...
# 1     7931  An Act for granting to Her Majesty certain sum...
# 2     7880  An Act to amend the Criminal Code (victim surc...
# 3     7769  An Act to amend the Income Tax Act (tax credit...
# 4     1882  An Act to amend the Transportation of Dangerou...
#
#               status_code   law                             text_docid  \
# 0        RoyalAssentGiven  True  [9013230, 9256936, 9332834, 10276765]
# 1        RoyalAssentGiven  True                     [8852843, 8838618]
# 2       HouseAt2ndReading  None                              [8520485]
# 3  WillNotBeProceededWith  None                              [8126924]
# 4        RoyalAssentGiven  True                              [3944893]
#
#                                           bill_texts  \
# 0  [{'docid': 9013230, 'text_en': 'Bill
# C-51
# LEGI...
# 1  [{'docid': 8852843, 'text_en': 'Cover
# Summary
# ...
# 2  [{'docid': 8520485, 'text_en': 'Criminal Code
# ...
# 3  [{'docid': 8126924, 'text_en': 'Income Tax Act...
# 4  [{'docid': 3944893, 'text_en': 'Second Session...
#
#                                       vote_questions
# 0  [{'id': 3349, 'description_en': 'Time allocati...
# 1  [{'id': 2602, 'description_en': 'That the Bill...
# 2                                                 []
# 3  [{'id': 2507, 'description_en': 'That the Bill...
# 4  [{'id': 313, 'description_en': 'That the Bill ...

# %%
final_dfs = ['df_bills_merged', 'df_statement_per_document']

# Show current working directory
print("Exporting to directory:", os.getcwd())

for df_name in final_dfs:
    # Retrieve the DataFrame object
    df = globals().get(df_name)
    if df is None:
        print(f"DataFrame '{df_name}' not found.")
        continue

    # Convert to list of dicts
    docs = df.to_dict(orient='records')
    
    # Filename to write
    filename = f'{df_name}.json'
    
    # Write out to JSON with pretty indentation
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(docs, f, indent=2, ensure_ascii=False)
    
    print(f"Written {len(docs)} records to {filename}")
# Out:
# Exporting to directory: /Users/joey/Desktop/neurips-2025
# Written 5569 records to df_bills_merged.json
# Written 18200 records to df_statement_per_document.json
