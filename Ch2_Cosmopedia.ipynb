# %% [markdown]
# <a href="https://colab.research.google.com/github/piesauce/llm-playbooks/blob/ateng%2FCH2_exercises/Ch2_Cosmopedia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 2 Exercises - Cosmopedia Exploration
#
# Load cosmopedia-100K, a subset of the cosmopedia dataset and explore the prompts as well as the resulting synthetic data. What does the quality of the synthetic data look like? Do you observe any factual or reasoning errors? Additionally, try varying the prompts and see if you can generate more diverse data.
#
# Here's the link to Cosmopedia via HuggingFace Datasets: https://huggingface.co/datasets/HuggingFaceTB/cosmopedia-100k

# %%
# load the dataset
# !pip install -q datasets

from datasets import load_dataset

dataset = load_dataset("HuggingFaceTB/cosmopedia-100k", split="train")

# %%
# look at examples from the dataset
for idx in range(5):
    sample = dataset[idx]
    print(f"Sample {idx+1}:")
    for k, v in sample.items():
        print(f"  {k}: {v}")
    print("-----")
# Out:
# Sample 1:
#   prompt: Here is an extract from a webpage: "What can cause my settlement offer to be delayed?
# When you’ve been injured in an Austin truck accident, one of the most common questions is how long it will take for the insurance company to make an offer to settle your case. The answer depends on a variety of factors.
# The process starts with filing an insurance claim and providing evidence that shows exactly what happened during the accident and who was at fault. This can involve gathering key Austin truck accident evidence such as:
# - Medical records
# - Photographs or video footage of the crash scene
# - Witness statements
# - Other documents related to your injuries and damages.
# Once this information has been collected by both sides, negotiations may begin between your Austin truck accident lawyer and the insurance company on how much compensation should be offered in exchange for settling the case out of court.
# It is important to remember that every truck accident case is unique so there is no set timeline as far as when a settlement mig".
#
# Write an informative and insightful blog post that expands upon the extract above. Your post should delve into the nuances of the topic, offering fresh perspectives and deeper analysis. Aim to:
#
# - Inform: Provide valuable, well-researched information that educates the reader.
# - Engage: Write in a conversational tone that connects with the audience, making complex ideas accessible.
# - Illustrate: Use examples, anecdotes, or personal experiences to bring the topic to life.
# Do not give a title and do not start with sentences like "Have you ever..." or "Hello dear readers..", simply write the content without these introductory phrases.
#   text_token_length: 585
#   text:  When you've been involved in an auto accident, particularly one involving a commercial truck, receiving a settlement offer from the insurance company is often top of mind. After all, medical bills, lost wages, and property damage can quickly add up, leaving you financially strained. However, the timing of a settlement offer can vary greatly depending on several factors. Let's delve deeper into the nuances of this topic.
#
# First and foremost, before any settlement negotiation can occur, it's crucial to establish liability. Gathering evidence such as medical records, photographs, witness statements, and other relevant documentation helps build a solid foundation for your case. An experienced Austin truck accident attorney can guide you through this process and ensure that all necessary evidence is gathered and presented effectively.
#
# One factor that can significantly impact the timeline of a settlement offer is the complexity of the case itself. For instance, if multiple parties are involved, determining responsibility becomes more intricate, potentially delaying the settlement process. Additionally, cases involving severe injuries usually require extensive medical evaluations and treatment plans, which takes time to compile and present accurately.
#
# Another critical aspect influencing the speed of a settlement offer is communication between the two negotiating parties – i.e., your legal representative and the insurance adjuster. While some adjusters work diligently to resolve claims swiftly, others might employ stall tactics designed to lowball offers or wear down claimants. Patience and perseverance are essential here; attempting to rush the process could result in a lower payout than what you rightfully deserve.
#
# Furthermore, keep in mind that each case is unique, meaning there's no standard timeline for receiving a settlement offer following a truck accident. Some claims may reach resolution within months, while others might drag on for over a year due to unforeseen complications or disputes. It's vital to stay informed throughout the process, maintaining open lines of communication with your attorney to understand where things stand and what to expect moving forward.
#
# Lastly, consider mediation as a viable option if negotiations become tense or protracted. Mediators act as impartial third parties who facilitate discussions between opposing counsel, aiming to find middle ground and expedite resolutions. By bringing in a mediator, both sides agree to compromise, often leading to faster (and fairer) outcomes.
#
# In conclusion, various elements contribute to the length of time it takes for a settlement offer after an Austin truck accident. Building a strong case through thorough evidence collection, exercising patience during negotiations, and considering alternative dispute resolution methods can help streamline the process. Remember, staying informed and working closely with an experienced truck accident lawyer increases your chances of securing a favorable outcome, even if it requires a bit of waiting.
#   seed_data: web_samples_v2
#   format: blogpost
#   audience: general
# -----
# Sample 2:
#   prompt: Here is an extract from a webpage: "The LISA Pathfinder scientific collaboration will meet in Trento, together with key representatives of the space agencies and industries that made the mission possible, to discuss the scientific results and to celebrate the outstanding success of the mission.
# LISA Pathfinder is the European Space Agency (ESA) precursor mission to the LISA space-based gravitational wave observatory that the agency is developing within the Cosmic Vision Programme. LISA Pathfinder has been developed within an international collaboration led by ESA and including the space agencies of France, Germany, Italy, Spain, Switzerland, The Netherlands and United Kingdom, and NASA.
# LISA Pathfinder has demonstrated that the sophisticated space-time measurements that are the core metrology for a gravitational wave observatory are indeed feasible, at and beyond the precision required by LISA, a leap of several orders of magnitude in the field of gravitational physics.
# As a consequence of these results, even exceeding t".
#
# Write an extensive and detailed course unit suitable for a textbook targeted at college students, related to the given extract within the context of "Astronomy and Astrophysics". This unit should explore all pertinent concepts with in-depth explanations and technical detail. Focus on:
#
# - Rigor: Ensure in-depth coverage of the concepts.
# - Engagement: Write with an academic, professional and engaging tone that captivates interest.
# - Application: Incorporate specific, practical examples, such as proofs in calculus or critical dates and figures in history. Do not use images.
#   text_token_length: 896
#   text:  Course Unit: LISA Pathfinder Mission and Gravitational Wave Detection
#
# 1. Introduction
# Gravitational waves are ripples in spacetime caused by some of the most violent and energetic processes in the Universe, such as colliding neutron stars or merging black holes. These waves were first predicted by Albert Einstein in 1916 as part of his general theory of relativity, but they have never been directly detected until recently. The Laser Interferometer Space Antenna (LISA) Pathfinder mission, launched in December 2015, was a crucial step towards detecting gravitational waves from space. This course unit explores the science behind gravitational waves, the LISA Pathfinder mission, its objectives, achievements, and implications for future astrophysical research.
# 2. Gravitational Waves: Concept and Significance
# Gravitational waves are disturbances in the curvature of spacetime generated by accelerating massive objects. They propagate outward from their source like waves on water, carrying unique information about their cataclysmic origins and providing insights into the nature of gravity itself. Detecting and measuring gravitational waves can help us understand how the universe works, test our theories of gravity, and open up new ways of studying phenomena we cannot observe any other way.
# 3. The LISA Pathfinder Mission
# The LISA Pathfinder mission was designed to demonstrate technology necessary for detecting gravitational waves from space. It tested the fundamental technologies required for LISA, which includes drag-free flight, high-precision interferometry, and low-noise laser systems. By demonstrating these technologies, LISA Pathfinder paved the way for a full-scale space-borne gravitational wave detector capable of making observations impossible from Earth-based detectors.
# 4. Objectives and Achievements of LISA Pathfinder
# The primary objective of LISA Pathfinder was to validate free-fall motion control and measure the performance of micro-Newton thrusters used to keep the spacecraft centered on a pair of cubes separated by just 38 cm. Additionally, it aimed to prove that two independent objects could be put in free fall and kept under control at the level needed for LISA's detection sensitivity. Both objectives were achieved successfully.
# 	* Free-Falling Cubes: LISA Pathfinder carried two identical gold-platinum cubes weighing approximately 2 kg each. These cubes were placed inside electrode housings, which created an electric field around them. By applying voltages to the electrodes, scientists controlled the position and orientation of the cubes precisely, allowing them to maintain their relative positions to better than one billionth of a meter over time scales of minutes to hours.
# 	* Low Noise Measurement System: To achieve the desired accuracy, LISA Pathfinder incorporated a highly sensitive measurement system based on laser interferometry. The system measured changes in distance between the two cubes down to 10 pm (picometers), equivalent to one ten-millionth of the diameter of a human hair. Moreover, this level of precision surpassed what was initially envisaged for LISA Pathfinder by more than a factor of three.
# 5. Implications for Future Research
# With the successful completion of the LISA Pathfinder mission, researchers now have confidence that a full-scale space-based gravitational wave observatory can deliver the expected sensitivity levels. Furthermore, it opened doors for various applications, including testing general relativity further, probing the early universe, understanding supermassive black hole formation, and much more. As a result, the European Space Agency approved the LISA mission, scheduled for launch in the late 2030s, aiming to make direct detections of gravitational waves from space finally.
#
# Conclusion
# The LISA Pathfinder mission represents a significant milestone in astronomy and astrophysics, advancing humanity's ability to study the cosmos through gravitational waves. Its groundbreaking technological advancements have laid the foundation for the next generation of space-based observatories, promising unprecedented insight into previously unobservable aspects of our universe.
#   seed_data: web_samples_v1
#   format: textbook_academic_tone
#   audience: college_students
# -----
# Sample 3:
#   prompt: Here is an extract from a webpage: "Recording of Present Day: Math’s Greatest Hits, “Analysis” with Alex Kontorovich
# This is a recording of a live-streamed event that took place on Monday, November 16, 2020.
# Appropriate for ages 14 and up.
# Please note that MoMath’s video recordings are meant to be viewed by only you — kindly do not show this video to others, distribute it, or post it to social media.
# To learn about MoMath’s policies regarding video recordings, visit videos.momath.org.".
#
# Write an informative and insightful blog post that expands upon the extract above within the context of "Education". Your post should delve into the nuances of the topic, offering fresh perspectives or deeper analysis. Aim to:
#
# - Inform: Provide valuable, well-researched information that educates the reader.
# - Engage: Write in a conversational tone that connects with the audience, making complex ideas accessible.
# - Illustrate: Use examples, anecdotes, or personal experiences to bring the topic to life.
#
#   text_token_length: 701
#   text:  Title: Making Mathematics Accessible: The Importance of Age-Appropriate Content and Video Recordings
#
# Introduction
#
# The world of mathematics can often seem intimidating and exclusive, but efforts to make it more approachable and engaging have been gaining traction. One such organization working towards broadening accessibility to math concepts is the Museum of Mathematics (MoMath), which recently hosted a live-streamed event titled "Present Day: Math's Greatest Hits – Analysis" featuring mathematician Alex Kontorovich. This blog post will explore how age-appropriate content and video recordings play crucial roles in fostering mathematical literacy among diverse audiences.
#
# Age Appropriateness
#
# When discussing mathematics education, tailoring material to specific age groups ensures better comprehension and engagement. By targeting individuals aged 14 years and older, events like "Math's Greatest Hits" provide relatable yet challenging topics for teenagers who may not otherwise encounter advanced mathematical theories in their curriculum. Moreover, preparing age-specific materials encourages young learners to develop critical thinking skills progressively while maintaining enthusiasm throughout their educational journey.
#
# Accessibility through Video Recordings
#
# In today's digital era, video recordings offer unparalleled opportunities for disseminating knowledge across vast geographical distances. They also enable users to revisit lectures at their convenience, allowing them to absorb intricate concepts at their own pace. As noted in the MoMath policy statement mentioned earlier, these resources must respect copyright laws and intellectual property rights. However, when shared responsibly, they serve as powerful tools for democratizing learning and promoting inclusivity in mathematics education.
#
# Fresh Perspective: Breaking Barriers in Mathematics Communication
#
# Mathematical communication has long suffered from elitism due to its historical association with geniuses and prodigies. Nevertheless, recent initiatives aim to bridge this gap between experts and novices by presenting sophisticated ideas using everyday language and visual illustrations. For instance, during his presentation, Alex Kontorovich explained abstract concepts in number theory through music, demonstrating how seemingly disparate fields intersect and enrich one another. Such innovative approaches foster curiosity and encourage lifelong learning, especially among those who might initially perceive mathematics as dry and disconnected from reality.
#
# Illustration: Personal Experiences with Digital Learning
#
# As someone passionate about both mathematics and technology, I have personally benefited from high-quality online resources. During my undergraduate studies, attending recorded lectures allowed me to review difficult topics multiple times before examinations, ultimately contributing to improved performance. Furthermore, participating in virtual conferences introduced me to prominent researchers worldwide, expanding my professional network beyond local boundaries. Consequently, I advocate for increased availability and responsible use of digital learning materials to empower students and enthusiasts alike in mastering mathematical principles.
#
# Conclusion
#
# Organizations like MoMath recognize that effective mathematics education requires adaptability and creativity. Through age-appropriate content and strategic utilization of video recordings, they break down barriers preventing wider participation in STEM disciplines. Encouraging open dialogue around once esoteric subjects creates fertile ground for future discoveries and innovations, transforming our society into a truly inclusive meritocracy where everyone has equal opportunity to excel in mathematics.
#   seed_data: web_samples_v1
#   format: blogpost
#   audience: general
# -----
# Sample 4:
#   prompt: Here is an extract from a webpage: "DoP Jules O'Loughlin ASC ACS Talks Us Through Angel Has Fallen
# Angel Has Fallen (2019) is the third instalment in the 'Fallen' film franchise, following Olympus Has Fallen (2013) and London Has Fallen (2016). Directed by Ric Roman Waugh (Shot Caller, Snitch, and Felon) and staring Gerard Butler, Morgan Freeman and Jada Pinkett Smith, this blockbuster's storyline follows United States Secret Service agent Mike Banning (Butler) as he races against time to clear his name after being framed for an assassination attack on the US President, Allan Trumbull (Freeman).
# "Like a lot of films these days you are faced with a brutal shooting schedule. Filmmaking has to be done at speed whilst maintaining a high level of quality. With 'Angel Has Fallen', we had a very tight schedule coupled with several unforeseen complications"
# Following his work on 'The Hitman's Bodyguard' Director of Photography Jules O'Loughlin ASC ACS, who has built a solid resume of great action projects with strong dramatic pe".
#
# Write an informative and insightful blog post that expands upon the extract above, within the context of "Performing Arts". Your post should delve into the nuances of the topic, offering fresh perspectives and deeper analysis. Aim to:
#
# - Inform: Provide valuable, well-researched information that educates the reader.
# - Engage: Write in a conversational tone that connects with the audience, making complex ideas accessible.
# - Illustrate: Use examples, anecdotes, or personal experiences to bring the topic to life.
# Do not give a title and do not start with sentences like "Have you ever..." or "Hello dear readers..", simply write the content without these introductory phrases.
#   text_token_length: 808
#   text:  The Performing Arts encompass many different forms of artistic expression, including theater, dance, music, and film. Each form requires its own unique set of skills and techniques, but they all share one common goal: to tell a story and elicit emotion from the audience. One crucial aspect of performing arts production is cinematography, which involves capturing visual elements of a performance through photography and camera movements. This art form plays a significant role in shaping the viewer’s experience, particularly in the world of action movies such as “Angel Has Fallen.”
#
# Director of Photography (DoP), Jules O’Loughlin ASC ACS, played a pivotal role in bringing the fast-paced action sequences and intense drama to life in “Angel Has Fallen,” the latest installment in the ‘Fallen’ film franchise. Cinematographers must balance technical expertise with creative vision while navigating challenging circumstances during filmmaking. According to O’Loughlin, “Filmmaking has to be done at speed whilst maintaining a high level of quality. With ‘Angel Has Fallen’, we had a very tight schedule coupled with several unforeseen complications.” Despite the hurdles encountered throughout production, O’Loughlin managed to capture breathtaking shots and deliver visually stunning scenes.
#
# In order to create dynamic images under pressure, DoPs rely on their ability to adapt quickly and think outside the box. For instance, when working on a project with limited resources or time constraints, it may become necessary to modify lighting arrangements or adjust camera angles to achieve desired effects more efficiently. Additionally, mastery over various cameras and lenses enables them to make informed decisions about how best to portray specific moments within the narrative.
#
# One example of O’Loughlin’s resourcefulness can be seen in his use of handheld camera work during some of the film’s most intense action sequences. By employing this technique, he was able to convey a sense of urgency and chaos, immersing viewers in the heart of the scene. Furthermore, strategic placement of cameras allowed him to showcase impressive stunts and fight choreography without sacrificing clarity or coherence.
#
# Another essential aspect of a DoP’s job is collaborating closely with the director to ensure their collective vision aligns with the overall aesthetic goals of the project. In the case of “Angel Has Fallen,” O’Loughlin worked alongside director Ric Roman Waugh (known for his previous works Shot Caller, Snitch, and Felon) to craft a visceral and engaging viewing experience. Their collaboration resulted in a seamless blend of adrenaline-pumping action and character-driven drama, supported by O’Loughlin’s expert camerawork.
#
# Moreover, color grading also plays a critical role in establishing mood and atmosphere within a film. Skilled cinematographers manipulate colors to evoke particular emotions, guide attention toward specific elements within the frame, or provide context regarding setting and time period. As evident in “Angel Has Fallen,” O’Loughlin utilized warm tones and desaturated hues to emphasize the raw intensity of the protagonist’s struggle and maintain consistency across various locations featured throughout the movie.
#
# Cinematography serves as an integral component of performing arts, especially within the realm of film production. It demands both technical proficiency and imaginative flair, allowing skilled artists like Jules O’Loughlin ASC ACS to elevate stories beyond mere words and transform them into memorable visual experiences. Overcoming obstacles presented by demanding schedules and unexpected challenges, O’Loughlin successfully delivered striking imagery that resonated deeply with audiences worldwide – further cementing his reputation as a talented DoP capable of handling even the most complex action projects.
#   seed_data: web_samples_v2
#   format: blogpost
#   audience: general
# -----
# Sample 5:
#   prompt: Write an educational story (3-5 paragraphs) targeted at young children using simple words. The story should be inspired from this text snippet:
# “Not all women in skirts and man in khakis walk past an Armani billboard walk to go to work.
# This justifies what answer for what question? Q & A:
# Question: Do all people wearing skirts or khakis walking past an Armani billboard go to work?
#
# Answer: No, not all women in skirts and men in khakis walking past an Armani billboard are going to work. People have various reasons for being in a particular location, and their clothing and surroundings do not always indicate their destination or purpose.”
#
# The story doesn’t have to be addressing everything in the snippet, it is there just for inspiration.
# The story should have the following features:
# - Science integration: embed basic science concepts within the story, explaining them through the characters' adventures and discoveries. For example, if the story includes a scene where characters are looking at the sky, you could have them wonder why it's blue and explain the physics behind in grade school level.
# - Dialogue: include at least one dialogue and insightful conversation.
# - Unexpected twist: conclude with a twist that doesn't resolve as hoped, but leaves a clear lesson about life and science.
# Do not start with classic sentences like "Once upon a time", be creative.
#   text_token_length: 497
#   text:  It was a bright, sunny day and Maria was excited to wear her new skirt to school. She loved how twirly it was when she spun around! As she walked to the bus stop, she saw Mr. Johnson, her neighbor, dressed in his usual khaki pants, watering his lawn.
#
# "Hi Maria!" he called out, waving his free hand. "Off to school?"
#
# Maria nodded and waved back. "Yup! I love my new skirt."
#
# Mr. Johnson chuckled. "Well, you know, not everyone who wears skirts is going to school, just like not everyone in khakis is watering their lawn."
#
# Maria tilted her head in confusion. "What do you mean, Mr. Johnson?"
#
# He turned off the hose and walked over to join her on the sidewalk. "See that lady across the street? She's wearing a skirt too, but she's not going to school. And see those kids playing soccer in the park? They're wearing shorts, but they're definitely not going to school either."
#
# Maria looked around and noticed that indeed, there were lots of different people wearing all sorts of clothes, doing all sorts of things. Some people in suits were getting into fancy cars, while others in workout gear were jogging down the street.
#
# "So," Maria said slowly, trying to understand, "clothes don't tell us what someone's doing?"
#
# Mr. Johnson shook his head. "Nope. Just because someone looks a certain way, it doesn't mean we can assume anything about them. We need to ask questions and learn more before we make assumptions."
#
# Just then, the school bus pulled up and honked its horn. Maria gave Mr. Johnson a quick hug goodbye and climbed aboard. But as she took her seat, she couldn't help but think about what he had said. Maybe next time she saw someone new, she wouldn't jump to conclusions based on how they looked. Instead, she would try to get to know them better first.
#
# And so Maria learned a valuable lesson that day - not only about how to approach strangers, but also about how appearances can be deceiving. Even though she didn't realize it yet, this lesson would serve her well throughout her entire life.
#   seed_data: openhermes2.5
#   format: story_children
#   audience: young_children
# -----

# %% [markdown]
# As seen above, in many synthetic data corpora, you might see a structure like:
#
#     prompt: The original system or user prompt used to generate text.
#     response or text: The AI-generated answer or text snippet.
#     Possibly additional metadata: temperature, model, date of generation, text_token_length, etc.

# %% [markdown]
# ## Assessing the Quality of Synthetic Data
#
# Synthetic text from language models can be coherent and fluent, but it may exhibit:
#
# - Factual inaccuracies: The model can “hallucinate” facts, misquote sources, or provide incorrect details.
# - Reasoning errors: It might produce reasoning that seems logical on the surface but contains subtle contradictions or leaps.
# - Stylistic uniformity: If prompts or generation hyperparameters are not varied, the text can start to sound repetitive, especially with the same tone or structure.
#
# However, based on the 5 samples above, the synthetic samples look surprisingly coherent and well-structured. Each example fulfills the requested style or format (e.g., blog post, academic tone, children's story) and stays on-topic. The writing flows smoothly, with appropriate transitions and readable paragraph structure. The text tends to be grammatically sound and largely stylistically consistent—hallmarks of modern large-language-model-generated text.
#
#     Factual Accuracy
#         In the LISA Pathfinder example (Sample 2), references to the mission’s purpose (testing drag-free flight, laser interferometry), plus mentions of ESA, NASA, and the timeline, seem consistent with known facts. The text states that LISA Pathfinder launched in December 2015, which matches the actual historical launch date (December 3, 2015). These details appear largely correct rather than random hallucinations.
#         In the “Angel Has Fallen” text (Sample 4), references to the film’s premise (Gerard Butler as Mike Banning, Morgan Freeman as President Trumbull, directed by Ric Roman Waugh) are also correct. The mention of the film’s tight schedule and the cinematographer Jules O’Loughlin ASC ACS lines up with real production constraints often cited in interviews.
#         The truck accident blog post (Sample 1) is generally coherent about how settlements might be delayed, what factors contribute (e.g., gathering evidence), and how legal negotiations work. It doesn’t contain glaring factual errors or absurd claims.
#         The mention of the “MoMath” event in Sample 3 is plausible, but the user would need to confirm if any references to the math talk or the content about Alex Kontorovich’s approach are 100% accurate. At a glance, it appears consistent with typical math outreach events.
#         The children’s story (Sample 5) is mostly fictional/educational; it’s not heavily reliant on real-world facts beyond the general theme of “don’t judge by appearances.”
#
# In short, no major factual inaccuracies jump out. However, one should keep in mind that synthetic data can still contain subtle errors. If these texts were integrated into a real publication or used as training data, a human fact-check would still be recommended.
#
#     Reasoning and Logical Flow
#         The samples generally follow a coherent line of reasoning: They introduce a topic, expand on it, and draw conclusions (e.g., “here’s what can delay a settlement,” “here’s how LISA Pathfinder demonstrates technology for gravitational wave detection,” etc.).
#         The text in each sample stays on theme and transitions well among points (for example, Sample 2 logically moves from explaining gravitational waves to describing LISA Pathfinder’s technology demonstrations).
#         There are no blatant contradictions or nonsensical jumps in reasoning across the shown excerpts.
#
#     Stylistic Observations
#         The texts follow the user instructions fairly closely (e.g., no “Hello dear readers…” in the performing arts post of Sample 4, or the children’s story adds science bits as requested).
#         The tone is consistent with each specified format (blog post, academic course unit, children’s story).
#         In some places, the text uses transitional phrases in a similar manner. This slight formulaic style can sometimes signal AI-generated text, but it remains coherent.
#
#     Potential Limitations
#         Overconfidence: AI-generated text can sound quite certain, even on complex or specialized topics. Without thorough referencing, it’s easy to slip in smaller inaccuracies (e.g., the exact date or mission detail).
#         Repetitive Patterns: There are occasional repeated phrases (“It is crucial to…” or “One factor that can…”). This can indicate the text is pulling from a learned pattern or template.
#         Lack of Citations: Except for references to actual facts/figures, there are no formal citations or footnotes. This is common in synthetic text but also means verifying precise claims can be harder.
#
# Although, again note that we only looked at 5 samples here for illustration. :)

# %% [markdown]
# ## Varying the Prompts for More Diverse Outputs

# %%
# !pip install transformers

from transformers import pipeline
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
# Load a text-generation model of your choice; for demonstration, we'll use GPT-2 because it's easily available on HF ehre https://huggingface.co/openai-community/gpt2
generator = pipeline("text-generation", model="gpt2")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
generator

# %%
# Define base snippet to expand on, simlar to the examples above

base_snippet = (
    "Here is an extract from a webpage: "
    '"The LISA Pathfinder scientific collaboration will meet in Trento '
    'to discuss the outstanding success of the mission..."'
    "\n\n"
    "Write an extensive and detailed course unit suitable for a textbook targeted at college students."
)

# A list of style prompts or instructions to prepend or append
style_variations = [
    "In a highly technical, academic style:",
    "In a conversational, first-person narrative:",
    "As a short, playful summary under 150 words:",
    "Rewrite with bullet points and short paragraphs:",
]

# %%
# Generate text for each variation
# We'll loop over these variations, constructing a combined prompt each time.
# We'll also play with generation hyperparameters (e.g., temperature for creativity, top_k for sampling diversity) to see how it affects the output.

for idx, style_instruction in enumerate(style_variations):
    # Combine the style instruction + base snippet into a single prompt
    prompt = f"{style_instruction}\n\n{base_snippet}\n\n"

    # Generate text with specific parameters for diversity
    output = generator(
        prompt,
        max_length=300,         # limit the maximum tokens
        temperature=1.2,        # higher temperature -> more randomness in sampling
        top_k=50,               # sample only from the top_k most likely tokens
        top_p=0.9,              # or use nucleus sampling for additional control
        num_return_sequences=1,  # generate only one sequence this round
        do_sample=True          # enable sampling (rather than greedy decoding)
    )

    # Print or store the result
    print(f"--- Variation {idx+1} ---")
    print(f"PROMPT:\n{prompt}")
    print("GENERATED TEXT:\n", output[0]["generated_text"])
    print("------------------------------------------------\n")
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# --- Variation 1 ---
# PROMPT:
# In a highly technical, academic style:
#
# Here is an extract from a webpage: "The LISA Pathfinder scientific collaboration will meet in Trento to discuss the outstanding success of the mission..."
#
# Write an extensive and detailed course unit suitable for a textbook targeted at college students.
#
#
# GENERATED TEXT:
#  In a highly technical, academic style:
#
# Here is an extract from a webpage: "The LISA Pathfinder scientific collaboration will meet in Trento to discuss the outstanding success of the mission..."
#
# Write an extensive and detailed course unit suitable for a textbook targeted at college students.
#
#
# This section discusses the mission of the team:
#
# How long is it taken to complete your project? A team would be expected to have about five-six weeks to complete a project at one school in the country. A school that does not have a complete project of the sort (for example, a research school) will typically take longer than this.
#
# Why do they not do more?
#
# These are not questions regarding the "next chapter" at each school. "What's in this next chapter of the science of evolution?" The point is simply: do not work more than a week after the actual goal is reached. There is an expectation of "just as soon", that is that it takes about ten days for students to be able to write a thesis after the entire project has been completed. "Why should I care?" are the most important questions that this project must be completed before the whole research team can make any further discoveries. What matters is not that we are working more than a week but that we have a deadline for a full working effort by one academic or other to arrive at an agreement (which could involve some of us working on another project and have the agreement terminated by
# ------------------------------------------------
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# --- Variation 2 ---
# PROMPT:
# In a conversational, first-person narrative:
#
# Here is an extract from a webpage: "The LISA Pathfinder scientific collaboration will meet in Trento to discuss the outstanding success of the mission..."
#
# Write an extensive and detailed course unit suitable for a textbook targeted at college students.
#
#
# GENERATED TEXT:
#  In a conversational, first-person narrative:
#
# Here is an extract from a webpage: "The LISA Pathfinder scientific collaboration will meet in Trento to discuss the outstanding success of the mission..."
#
# Write an extensive and detailed course unit suitable for a textbook targeted at college students.
#
#
# This group consists of over 200 people from all levels of academia, from middle school through junior high, who are working in collaboration in a high-tech world.
#
# What does this mean in practice?
#
# A student on the project team will be given an overview of a project, written in English in a concise, easy-to-remember and authoritative way. The individual has to agree to attend a particular class or have their academic information approved by the project committee to be presented at their next conference. After all, "The LISA Pathfinder aims to expand collaboration by providing student groups with an objective assessment system as their basis for learning. Students can participate by doing simple hands-on exercises, discussing problems and sharing observations with other colleagues on the project, using their experience and knowledge of physics as well as their ability to explain concepts and experiments." In short, students will get to meet the mission, write one of four introductory classes which will help the students on each project, and meet up with scientists involved. The course is based on a project by a different student group (known as the Science Group), who all also do a similar course with a more specific mission in mind.
#
#
# ------------------------------------------------
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# --- Variation 3 ---
# PROMPT:
# As a short, playful summary under 150 words:
#
# Here is an extract from a webpage: "The LISA Pathfinder scientific collaboration will meet in Trento to discuss the outstanding success of the mission..."
#
# Write an extensive and detailed course unit suitable for a textbook targeted at college students.
#
#
# GENERATED TEXT:
#  As a short, playful summary under 150 words:
#
# Here is an extract from a webpage: "The LISA Pathfinder scientific collaboration will meet in Trento to discuss the outstanding success of the mission..."
#
# Write an extensive and detailed course unit suitable for a textbook targeted at college students.
#
#
# In this course:
#
#
# * You will prepare a student's initial English-language textbook (the required two or three chapters will be required);
#
#
# * You will introduce yourself and how your assignment came about.
#
#
# * You will describe your course assignments and why their outcomes are important to you.
#
#
# * You will ask students who have completed a course to send you all an additional course unit and how this may help you with your preparation of your own textbook for use by future assignments.
#
#
# * You can ask yourself a number of important questions (for example, "What is the most important question in your research area?" and "How does the instructor help you decide if a course unit would be helpful?").
#
#
# * As you prepare your textbook with detailed examples of your assignment (such as for your own assignment, or for a particular book you already have prepared for use, or for your book with accompanying examples of other assignments), you may want to ask a question in each textbook that would benefit your student. For example, if you choose to assign an assignment on how to draw the shape of a circle for a textbook with four numbers, and the instructor will then answer
# ------------------------------------------------
#
# --- Variation 4 ---
# PROMPT:
# Rewrite with bullet points and short paragraphs:
#
# Here is an extract from a webpage: "The LISA Pathfinder scientific collaboration will meet in Trento to discuss the outstanding success of the mission..."
#
# Write an extensive and detailed course unit suitable for a textbook targeted at college students.
#
#
# GENERATED TEXT:
#  Rewrite with bullet points and short paragraphs:
#
# Here is an extract from a webpage: "The LISA Pathfinder scientific collaboration will meet in Trento to discuss the outstanding success of the mission..."
#
# Write an extensive and detailed course unit suitable for a textbook targeted at college students.
#
#
# The book includes a reference to the LISA Pathfinder program: "Project Gutenberg: The Digital Science of the LISA Pathfinder program, a comprehensive, hands-on course that offers a brief overview of all aspects of the computer science study. The work in the book includes an exploration of computer science, critical thinking, programming language theory and related subjects," while "The Digital Science of the LISA Pathfinder mission includes a detailed introduction to the computer science study that includes examples of software used by the organization." In each module, students write exercises and references to specific research areas in which the research can be analyzed.
#
# You can even use your university's digital library with LISA Pathfinder: "Create PDFs" for free.
#
#
# You can download free material directly from the digital library and share it with your friends and peers. In some countries, they're also free to use from public libraries.
#
# All of this information was produced by researchers from several well-known universities including the University of California at Berkeley and the University of Arizona. There is a clear connection between the mission and these universities which are leading the way on improving scientific quality, research and development. I would like to welcome any ideas
# ------------------------------------------------

# %% [markdown]
# - temperature=1.2: Increases “randomness” in token selection. A value around 1.0 is standard; going above that can yield more creative or less deterministic results.
# - top_k=50: The model chooses the next token only from the top 50 probable tokens.
# - top_p=0.9: Nucleus (top-p) sampling ensures the model samples from the smallest set of tokens whose cumulative probability exceeds 0.9.
# - do_sample=True: Enables sampling (rather than taking the highest-probability token every time).

# %% [markdown]
# Overall Quality & Key Takeaways of Examples Above
#
#     Prompt Echoing: Each variation repeats your entire instruction. GPT-2 often does this if the prompt is given as plain text rather than using an “instruction-tuned” approach (e.g., Flan-T5, GPT-NeoX chat, etc.).
#     Ignoring Instructions: The model disregards requests for technical detail, style constraints, or word limits. It rarely addresses the actual LISA Pathfinder context in a meaningful way.
#     Hallucinations: Much of the generated text is random or off-topic, discussing school projects, course timelines, or digital libraries rather than gravitational wave technology.
#     Not Factual: The output does not contain factual information about LISA, gravitational waves, or ESA. Instead, it inserts inaccurate or irrelevant details about “200 people in academia,” “the next chapter,” or “deadline for a working effort.”
#     Limited Depth: The content does not produce a “detailed course unit,” “first-person narrative,” or “playful summary,” failing to meet the instructions or address the snippet meaningfully.
#
# Why is this Happening?
#
#     GPT-2 is not instruction-tuned, so it often just regurgitates or partially modifies the prompt.
#     It’s an older, smaller model with limited context handling and a tendency to produce irrelevant text.
#     The prompts are given as direct text, which GPT-2 sees as “stuff to continue,” rather than instructions to follow.
#
# Possible Solutions
#
#     Use Instruction-Tuned or Chat Models
#         Models like Flan-T5, Llama 2 Chat, GPT-NeoXT Chat Models, or OpenAI’s ChatGPT are often much better at following style requests and not echoing the prompt verbatim.
#     Prompt Engineering
#         Add clear separators, such as "Context:\n<text>\n\nInstruction:\n<what to do>\n\nAnswer:\n".
#         Use no_repeat_ngram_size, limit max new tokens, or parse out the repeated portion.
#     In-Context Examples
#         Provide a short example of what you want (an example input + desired output) inside the prompt so the model can mimic that style.
#
#
# The outputs from GPT-2 in these four variations:
#
#     Mostly ignore your style requests,
#     Echo the prompt content, and
#     Produce random or irrelevant text about “projects” or “deadlines” instead of a coherent course unit about LISA Pathfinder.
#
# This behavior is common with non-instruction-tuned models. If you switch to a more advanced or instruction-tuned model (or significantly adjust your prompt structure and sampling strategy), you’ll likely see more on-topic, less repetitive, and higher-quality text.
