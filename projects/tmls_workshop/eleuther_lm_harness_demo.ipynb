# %%
# !git clone https://github.com/EleutherAI/lm-evaluation-harness
# !pip install -e lm-evaluation-harness
# Out:
# Cloning into 'lm-evaluation-harness'...
# remote: Enumerating objects: 26158, done.
# remote: Counting objects: 100% (6029/6029), done.
# remote: Compressing objects: 100% (500/500), done.
# remote: Total 26158 (delta 5796), reused 5558 (delta 5527), pack-reused 20129
# Receiving objects: 100% (26158/26158), 21.24 MiB | 18.89 MiB/s, done.
# Resolving deltas: 100% (18249/18249), done.
# Obtaining file:///content/lm-evaluation-harness
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 9.9 MB/s eta 0:00:00
# ...

# %%
# !python /content/lm-evaluation-harness/lm_eval/__main__.py \
    --model hf \
    --model_args pretrained=google/flan-t5-xl \
    --tasks hellaswag \
    --batch_size 16 \
    --device cuda
# Out:
# 2023-12-13:15:14:35,403 INFO     [utils.py:160] NumExpr defaulting to 8 threads.
# 2023-12-13 15:14:36.247077: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 15:14:36.247128: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 15:14:36.247157: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 15:14:37.363381: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# 2023-12-13:15:14:41,887 INFO     [__main__.py:132] Verbosity set to INFO
# ...
